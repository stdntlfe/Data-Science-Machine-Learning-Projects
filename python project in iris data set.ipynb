# %%
import numpy as np

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(color_codes=True)

# %%
df=pd.read_csv('iris.data')

# %%
df.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df=pd.read_csv('iris.data', header=-1)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
col_name=[ 'sepal length','sepal width','petal length', 'petal width', 'class']
df.columns=col_name

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal length    150 non-null float64
# sepal width     150 non-null float64
# petal length    150 non-null float64
# petal width     150 non-null float64
# class           150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
# None

# %%
print(iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
# None

# %%
print(iris.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
print(df.groupby('class').size())
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# # Visualization

# %%
import seaborn as sns

# %%
sns.pairplot(iris,hue='species',size=3,aspect=1)

# %%
iris.hist(edgecolor='Black', linewidth=1.2, figsize=(12,8))
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.violinplot(x='species' ,y ='sepal_length',data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='species' ,y ='sepal_width',data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='species' ,y ='petal_length',data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='species' ,y ='petal_width',data=iris)

# %%
iris.boxplot(by='species', figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000CDA7E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DD97438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DDCB898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E03FDD8>]], dtype=object)

# %%
pd.plotting.scatter_matrix(iris,figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D517A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D4D77B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E0C7DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DEB4978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DEE8F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DEE8FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DF4EF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DF8F4E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E0D9A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DF5CEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E144400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E17AEF0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E1BAA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E360EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E3A3780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E3E22B0>]], dtype=object)

# %%
sns.pairplot(iris,hue='species',diag_kind='kde')

# %% [markdown]
# # basic steps of using scikit learn
#
# ## 1. choose a class of model
# ## 2. choose a hyperparameters
# ## 3. arrange data into feature matrix and target array
# ## 4. fit model to data
# ## 5. apply trained model to new data

# %% [markdown]
# # Supervised Learning: Simple Linear Regression

# %%
x=10 * np.random.rand(100)

# %%
y=3 * x + np.random.randn(100)

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression(fit_intercept=True)
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
X= x.reshape(-1,1)
X.shape
# Out:
# (100, 1)

# %%
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.coef_
# Out:
# array([ 2.98496707])

# %%
model.intercept_
# Out:
# 0.13096733101954605

# %%
x_fit=np.linspace(-1,11)

# %%
X_fit=x_fit.reshape(-1,1)

# %%
y_fit=model.predict(X_fit)

# %%
plt.scatter(x,y)
plt.plot(x_fit,y_fit)
